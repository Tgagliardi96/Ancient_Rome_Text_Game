# %% [markdown]
# # Introduction to Ancient Rome Text Adventure

# %%
"""
    DocString:

    A) Introduction:
    This game wants to present war in the Ancient Rome. 
    Structured in five steps, it goes from the institutions, to the army, to the culture. In order to create an   enjoyable
    experience there is a crescent level of difficulties. It requires attention to the information
    and some logic.
    The final objective is to let the user, especially if non European, to discover a portion of 
    this empire playing a series of simple games.
   
    Phase 1: dispositions about conflict
    Phase 2: decision of the territory
    Phase 3: preparation of army
    Phase 4: choice of divinity
    Phase 5: completion of quote
   
    B)Known Bugs and/or Errors:

    At the last phase of the game, if a player fails there is the correct message to exit followed
    by the uncorrect message 'Complete the quote'.
    At the fourth stage, '1' as input for the visit to the oracle is not recognized anymore.

   
"""

# %% [markdown]
# The adventure starts: 5 steps to achieve the glory or fail the mission.
#
# If you are ready to be in charge of the Roman Army, go in front of the Senate and prepare your mission!

# %%
import random 

#Start of first phase with declaration of stage no.1

def senate_call():
    #Message of beginning of first phase followed by input to proceed
    
    print("You're going to start your Ancient Rome experience.\n")
    input(prompt = 'If you are ready to start press any key\n')
    
    #Declaration of name of player. Command capitalize to avoid lack of caps lock
    name = input(prompt = "Input your name:\n")
    name = name.capitalize()
    
    #Introduction in first phase. Insertion of input name in message.     
    print(f"""\nWelcome in the Senate of the Roman Empire, General {name}.
Senators have indicated you to be in charge of the next campaign against Barbarians. 
Many generals failed before you: will you serve Rome in this mission?
\n""")
    
    #Message to player on how to proceed. yes or no capitalized. Insertion of casefold to avoid lack of caps lock
    decision = input(prompt = "Indicate with Yes or No if you accept to start the campaign:\n")
    decision = decision.casefold()
    
    #Option for decision on previous command. Yes brings to second phase defined mission_preparation
    if decision == 'yes' in decision:
        print("""\nThe Senate welcomes your decision. You have full powers, so go to choose your troops.
        \nBut remember: come back as winner or do not come back at all.\n""")
        mission_preparation() 
        
    #Second option for decision on previous command. No stops the game and brings to fail declared at the end        
    elif decision == 'no' in decision:
        print("""\nThe Senate condemns your decision.\nYou will be destituted from the Army and exposed in the Colosseum.
        \nGood luck with the lions!\n""")
        fail()
        
    #Previous option comprehends only Yes or No as possibilities of answer. Any other message considered error and 
    #brings to the beginning of the game, defined senate_call
    else:
        print("""Please write Yes or No to express your decision\n""")
        senate_call()    

#Start of second phase with declaration of stage no. 2
def mission_preparation():
    
    #Message of beginning of second phase followed by general input to proceed
    print("""You are at the second stage of your mission.\nIt is time to choose the troops and the strategy.
You will now meet with the second-in-command.\n""")
    input(prompt = 'If you are ready to proceed press any key\n')

   #Recall of the grade assigned in the first part. Capitalization in case user doesn't do it    
    
    grade = input(prompt = "Declare your grade before meeting your second-in-command:\n")
    grade = grade.capitalize()
    
    #First input followed by second message to player. Explanation of decision to take concluded by question        
    print(f"""\nWelcome {grade}, I am honored to serve Rome with you.
You can choose where to deploy the troops.\nRome needs to fight in the German, Slovakian and Ukranian territories.
What is your choice?\n""")
    
    #Input to anwer to previous question. Prompt to inform on how to proceed
    #Game structured on three options. Chosen insertion of numbers to simplify player's experience
    choice = input(prompt = """
Choose the territory inserting one of three alternatives:
(Insert the number of your choice):\n

1 Germany

2 Slovakia

3 Ukraine
\n""")
    choice = choice.casefold()
    #Insertion of casefold to comprehend possible insertion of name options
    #Casefold followed by ifs. All three options allow player to continue even if inserts name instead of number
    
    #First if brings to third phase defined at the end as army
    if choice == '1': 
        print("""\nYou are a brave commander. German territories are very hostile. 
You will fight against the SVEVIANS tribes.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army()
        
    if choice == 'germany':
        print("""\nYou are a brave commander. German territories are very hostile. 
You will fight against the SVEVIANS tribes.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army() 
        
    #Second if brings to third phase. Player has to match exactly what is in the input, number or name of territory
    elif choice == '2':
        print("""\nWe count on your capabilities to win against this new enemy: the IAGIZIANS.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army()
        
    elif choice == 'slovakia':
        print("""\nWe count on your capabilities to win against this new enemy: the IAGIZIANS.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army()
        
    #Third if brings to third phase. Player has to match exactly what is in the input, number or name of territory
    elif choice == '3':
        print("""\nThis choice reflects your value. The SARMATIANS populations are very far from Rome.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army()
        
    elif choice == 'ukraine':
        print("""\nThis choice reflects your value. The SARMATIANS populations are very far from Rome.
We'll indicate you the characteristics of the territory to make you choose your troops.\n""")
        army()
                      
    #Any other option gives message of error and brings to beginning of phase
    #In previous ifs possibility to recogniize names if misspelled in last part, to consider especially for non Europeans
    else:
        print("\nYou have to choose one of the alternatives indicated.\n")
        mission_preparation()
        
def army():
    
    #Message of beginning of third phase followed by general input to proceed

    print("""You are at the third stage of your mission.\nNow you'll have to decide who will form your army.
Look at the characteristics of the territory to select the army.\n""")
    input(prompt = 'Press any key when you are ready to proceed.\n')

    #Second input. Message to the user to check what tribe was assigned

    enemy = input(prompt = """
Recall the name of the population you are going to fight and insert the correspondent number:
1 Svevians

2 Iagizians

3 Sarmatians
\n""")
    enemy = enemy.casefold()

    #Input modified with casefold. possible to proceed if number not inserted. casefold avoids lack of caps lock

    #First option. Recognisement restricted to number or name. Word recognised if incomplete. Information for next step

    if enemy == '1':
        print("""\nYou will fight in an alluvial plain created by the Danube river. 
Forests and woods are present and many Barbarians use them to hide during the battle.
\n""")
        
    if enemy == 'svevians':
        print("""\nYou will fight in an alluvial plain created by the Danube river. 
Forests and woods are present and many Barbarians use them to hide during the battle.
\n""")
        
    #Nested conditional. To every output corresponds choice of troops to make basing on information indicated before

    #Four options. Message to insert number instead of name

        troops = input(prompt = """
Choose what troops you'll bring between infantry, cavalry and archers
(input the number):\n
1 Entire army

2 Infantry and cavalry

3 Infantry and archers

4 Cavalry and archers
\n""") 

        #First if matches option no. 1 and brings to next stage
        
        if troops == '1':
            print("""\nExcellent choice! We will need all the army corpses to succeed.\n""")
            gods()

        #Second if matches options no. 3 and 4 and Brings to next stage but with message of attention to risks

        elif troops == '3' or '4':
            print("""\nRiskful choice, it will be difficult to win without our entire army.
But with our archers we can do it.\n""")
            gods()

        #Third if matches option no. 2. Message to indicate non performant choice, brings to fail

        elif troops == '2':
            print("""\nBad choice, it won't be possible to win without the archers.\n""")
            fail()

        #Any input not correspondent to numbers brings user to beginnig of phase with message to try again

        else:
            print("\nThere is something wrong. Please try again.\n")
            army()    

    #Second option. Recognisement of number and name. Name of tribe recognised without ending. Information for next step

    elif enemy == '2':
        print("""You will fight next to the river, which is used from the Barbarians as a point of strenght.
There aren't places where to hide, so the battles could last for a long time. 
\n""")
        
    elif enemy == 'iagizians':
        print("""You will fight next to the river, which is used from the Barbarians as a point of strenght.
There aren't places where to hide, so the battles could last for a long time. 
\n""")

        #Nested conditional. To every output corresponds choice of troops to make basing on information indicated before

        #Four options. Message to insert number instead of name of part of army

        troops = input(prompt = """
Choose what troops you'll bring between infantry, cavalry and archers
(input the number):\n
1 Entire army

2 Infantry and cavalry

3 Infantry and archers

4 Cavalry and archers
\n""")

        #First if matches option no. 1. Positive message, brings to next stage indicated as gods

        if troops == '1':
            print("""\nExcellent choice! In an open space like this every source has to be used to win.\n""")
            gods()

        #Second if maTches options no. 2 and 4. Brings to next stage but with moderate message 

        elif troops == '2' or '4':
            print("""\nGood choice, with the cavalry we could exploit the large spaces present there.\n""")
            gods()

        #Third if matches option no. 2. Brings to next phase but with message of attention about risks

        elif troops == '3':
            print("""\nRiskful choice, we could suffer the lack of support of the cavalry.
You'll need to elaborate a very strong strategy.\n""")
            gods()

        #Any input not correspondent to numbers not recognised. Brings user to beginnig with message to try again

        else:
            print("""\nThere is something wrong. Please try again.\n""")
            army()

    #Third option. Recognisement of number and name. #Name recognised without end. Message to provide information

    elif enemy == '3': 
        print("""You will fight in a region of mountains, where there are few open spaces like plains. 
In previous expeditions, Barbarians tried to bring our troops in little and closed spaces between mountains.
\n""")
        
    elif enemy == 'sarmatians':
        print("""You will fight in a region of mountains, where there are few open spaces like plains. 
In previous expeditions, Barbarians tried to bring our troops in little and closed spaces between mountains.
\n""")

        #Input composed by four options. Message to insert number instead of name of part of army

        troops = input(prompt = """
Choose what troops you'll bring between infantry, cavalry and archers
(input the number):\n
1 Entire army

2 Infantry and cavalry

3 Infantry and archers

4 Cavalry and archers
\n""")

        #First if matches option no. 3. Positive message, brings to next stage indicated as gods

        if troops == '3':
            print("""\nExcellent choice! This is a difficult territory where to fight.
The possibilities of success increase with the most agile corpses of our army\n""")
            gods()

       #Second if matches option no. 1. Brings to next phase but with message of attention about risks

        elif troops == '1':
            print("""\nRiskful choice. We could have difficulties to move the heaviest part of the army.\n""")
            gods()

       #Third if matches option no. 2. Message indicates non performant choice and brings to fail

        elif troops == '2' or '4':
            print("""\nBad choice, the cavalry will be useless in a strict territory like this.\n""")
            fail()

        #Any other input not recognised. Brings user to beginnig of phase with message to try again

        else:
            print("""\nThere is something wrong. Please try again.\n""")
            army()

#Insertion of else command for first input of enemy. Messages without number or name brings to begin of phase 

    else:
        print("""You didn't select one of the tribes. Please try again.\n""")
        army()
        
#Start of fourth phase with declaration of stage no.4

def gods():
    
    #Message of beginning of fourth phase followed by general input to proceed
    
    print("""You are at the fourth stage of your mission.
As every General, before departing you can visit the oracle and pray our gods.
Choose between one of them who will guide and protect your mission. \n""")

    #Choice for visit to oracle. Casefold allows to continue if option written without first letter capitalized
    
    oracle = input(prompt = """
Do you you want to visit the oracle for his prophecy? \n
1 Yes

2 No
\n""")
    
    oracle = oracle.casefold() 

    #Option for previous command. yes or 1 corresponds to positive message and brings to nested conditional
    
    if oracle == '1': 
        print("\nSoldiers will feel safe with the response of the oracle.\n")
        
    if oracle == 'yes':
        print("\nSoldiers will feel safe with the response of the oracle.\n")
        
        #Random choice between 3 different types of prophecy
        
        print("""How will the oracle interpretate your destiny? \nThe fate will decide for you. \n""")
        prophecy_method = ["Animal blood", "Birds fly", "Inspiration of oracle"]
        prophecy = (random.choice(prophecy_method))
        print(prophecy)
        
        #Nested conditional. Brings to choice of gods. Capitalize allows to continue if option written casefolded  
        
        roman_gods = input(prompt = """
Choose the god who will guide your mission
(Input the number):\n
1 Jupiter, father of Gods

2 Juno, mother of Gods

3 Minerva, goddes of war
    
4 Mars, god of war
\n""")
        roman_gods = roman_gods.capitalize()

        #First nested matches 1 or Jupiter and brings to next phase
        
        if roman_gods == '1':
            print("\nThe Father of Gods will protect your army.\n")
            speech()
            
        if roman_gods == 'Jupiter':
            print("\nThe Father of Gods will protect your army.\n")
            speech()
            
        #Second option matches 2 or Juno and brings to next phase
            
        elif roman_gods == '2':
            print("\nThe Mother of Gods will protect your army.\n")
            speech()
            
        elif roman_gods == 'Juno':
            print("The Mother of Gods will protect your army.\n")
            speech()

        #Third option matches 3 or Minerva and brings to next phase
            
        elif roman_gods == '3':
            print("\nYou made the best choice: to be protected by the divinity of war and smartness.\n")
            speech()
            
        elif roman_gods == 'Minerva':
            print("\nYou made the best choice: to be protected by the divinity of war and smartness.\n")
            speech()
        
        #Fourth option matches 4 or Mars and brings to next phase
        
        elif roman_gods == '4':
            print("\nYou made the best choice: to be protected by the father of the founders of Rome and divinity of war.\n")
            speech()
            
        elif roman_gods == 'Mars':
            print("\nYou made the best choice: to be protected by the father of the founders of Rome and divinity of war.\n")
            speech()

        #Else avoids other messages. In case of non correspondence, user fails with message explaining why            
            
        else:
            print("\nIt is impossible to go to war without the gods. You are not in charge anymore\n")
            fail()

    #Option for first command which corresponds to 2 or no #Brings to fail with message explaining why
            
    elif oracle == '2': 
        print("\nThe troops won't go to war without a prophecy.\n")
        fail()
        
    elif oracle == 'no':
        print("\nThe troops won't go to war without a prophecy.\n")
        fail()

    #Every other command not accepted. Brings to beginning of phase        
        
    else:
        print("\nSomething went wrong. Please try again.\n")
        gods()

#Start of last phase
def speech():

#Message to introduct to phase and input to win

    print("""Before starting the mission you have to motivate the soldiers.\n
Complete this famous quote for your speech to become the commander in chief:\n
'At my signal..' \n""")

    speech = 'unleash hell'
    speech_attempt = 2

    #While loop. Input to complete game
    while speech:
        spc_attempt = input(prompt = "Complete the quote :\n")
         #new configuration with convertion to integer and redefinition of if messages
            
        #First option of while loop. If matches with command, user wins and loop breaks
        
        if spc_attempt == speech:  
            print("\nTHAT IS CORRECT! YOU ARE READY FOR WAR!\n")
            input(prompt = """\nThanks for having played!
Press enter to finish the game \n""")
            break
            
        #Second option. In case player fails, while loop reduces to one attempt    
        
        elif spc_attempt != speech:
            speech_attempt -= 1
            
        #If attempts more than zero player has indicated number attempts remained    
        if speech_attempt > 0: 
              print(f"""\nThat's not what the soldiers want to hear. 
You have {speech_attempt} attempt remained.\n""")
                
        #Alternative in case of fail. If player fails for second time game ends        
        
        elif speech_attempt == 0: #add condition to counting
                print("""\nWatch 'The gladiator' to know what the Roman soldiers want to hear.\n""")
                fail() #bug in message: it appears even when player has still attempts
        
        #Else command to exclude any other answer
        else:
            print("Something was wrong. Pleasy try again\n")
            speech()
    
def fail():
    print("Thanks for having played!\n")
    input(prompt = 'Press any key to exit') 
    
senate_call()
